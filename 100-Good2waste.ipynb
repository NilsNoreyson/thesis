# %% [markdown]
# # General Aspects of $SnO_2$ based gas sensors
#
#
#
# ## Common preparation routes of $SnO_{2}$ materials
#
# ### SOl gel
#
# #### Morphologies and shape
#
# ### Flame spray pyrolysis
#
#
#
# #### Morphologies and shape
#
# ## Bulk properties of the SnO_{2}
#
# ## Work function
#
# ### Kelvin Probe
#
# ## Surface reactions
#
# ## Modelling for the transduction and reaction
#
# ### General principle of measurement
#
# ### Schottky approximation
#
# ### Boltzmann Approximation
#
# ### Effective density of states N_{C}
#
# ### Current models, State of the art

# %%
# %pylab
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize'] = ((1+5**0.5)/2*9,9)
from media.svgpath2mpl import parse_path
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
fig = figure()

with open('media/icons/escher.svg', 'r') as f:
    svg = f.read()
path = parse_path(svg)

graph = lambda t:(1+0.9*cos(8*t))*(1+0.1*cos(24*t))*(0.9+0.05*cos(200*t))*(np.random.choice([1,97,99],1)+sin(t))
p = np.linspace(-pi, pi,1000)
l = graph(p)

axe = subplot(4,2,(1,3), projection='polar')

axe.plot(p, l*10000,color='g')
axe.plot(p, l*5000,color='g')
#axe.set_axis_off()
axe.get_yaxis().set_visible(False)
axe.grid(b=True)
axe.set_title('The gras is always greener on the other side.')

axe = subplot(4,2,2)
axe.set_title('The fish is the marker.')
axe.scatter([0],[1],marker=path,s=10000)

axe = subplot(4,2,(2,4))
axe.set_title('There is plenty fish in the sea.')
d = np.random.rand(50,2)
sc = axe.scatter(d[:,0], d[:,1],c=d[:,0],marker=path,s=1)

d = np.random.rand(50,2)
sc = axe.scatter(d[:,0], d[:,1],c=d[:,0],marker=path,s=5000)


fig.savefig('media/example.png', dpi=300)
